# %%
# !pip install ultralytics roboflow -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 37.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 40.4 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 65.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 91.0 MB/s eta 0:00:00:00:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-adk 1.22.1 requires google-cloud-bigquery-storage>=2.0.0, which is not installed.
# bigframes 2.26.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-colab 1.0.0 requires google-auth==2.38.0, but you have google-auth 2.47.0 which is incompatible.
# ...

# %%
import os
import shutil
from ultralytics import YOLO
from roboflow import Roboflow
from IPython.display import FileLink

rf = Roboflow(api_key="EBfUGkJAAgSJn1GrpmXD")
project = rf.workspace("trn-xun-c").project("human-face-emotions-dxxni")
version = project.version(1)
dataset = version.download("yolov8")

print("\n✅ Đã tải dữ liệu xong!")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Human-face-emotions-1 in yolov8:: 100%|██████████| 28728/28728 [00:03<00:00, 9291.10it/s]
# ✅ Đã tải dữ liệu xong!

# %%
model = YOLO('yolov8s.pt') 

print("🚀 Bắt đầu Train Giai đoạn 1: Augmented & Small Model...")

results = model.train(
    data=f"{dataset.location}/data.yaml",
    
    # 1. Tăng số vòng học để model thẩm thấu dữ liệu
    epochs=50,             
    imgsz=640,
    patience=15,           
    batch=16,              
    
    # 2. CÁC THAM SỐ AUGMENTATION 
    degrees=15.0,          # Xoay ảnh +/- 15 độ 
    translate=0.1,         # Dịch chuyển ảnh 
    scale=0.5,             # Phóng to/nhỏ 50% 
    fliplr=0.5,            # Lật ảnh trái phải
    mosaic=1.0,            # Ghép 4 ảnh làm 1 
    mixup=0.1,             # Trộn 2 ảnh đè lên nhau 
    hsv_v=0.4,             # Thay đổi độ sáng 
    
    project='/kaggle/working/runs/detect',
    name='train_phase1_s_augment',
    exist_ok=True
)
# Out:
# ...
# 🚀 Bắt đầu Train Giai đoạn 1: Augmented & Small Model...
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
