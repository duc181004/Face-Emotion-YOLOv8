# %%
from roboflow import Roboflow
from ultralytics import YOLO
import os
from IPython.display import FileLink

rf = Roboflow(api_key="EBfUGkJAAgSJn1GrpmXD")
project = rf.workspace("trn-xun-c").project("human-face-emotions-dxxni")
version = project.version(1)
dataset = version.download("yolov8")

print("\n✅ Đã tải dữ liệu xong!")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Human-face-emotions-1 to yolov8:: 100%|██████████| 560156/560156 [00:17<00:00, 31290.98it/s]
# Extracting Dataset Version Zip to Human-face-emotions-1 in yolov8:: 100%|██████████| 28728/28728 [00:03<00:00, 9232.97it/s]
# ✅ Đã tải dữ liệu xong!

# %%
print("🚀 Bắt đầu train...")
model = YOLO('yolov8n.pt')

results = model.train(
    data=f"{dataset.location}/data.yaml",
    epochs=30,
    imgsz=640,
    project='/kaggle/working/runs/detect',
    name='train_kaggle',
    exist_ok=True
)
# Out:
# 🚀 Bắt đầu train...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 152.6MB/s 0.0s
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/Human-face-emotions-1/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=30, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train_kaggle, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/runs/detect, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/train_kaggle, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 43.8MB/s 0.0s
# Overriding model.yaml nc=80 with nc=8
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752872  ultralytics.nn.modules.head.Detect           [8, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,012,408 parameters, 3,012,392 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 129.9MB/s 0.0s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1148.6±419.4 MB/s, size: 37.8 KB)
# train: Scanning /kaggle/working/Human-face-emotions-1/train/labels... 11544 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 11544/11544 1.4Kit/s 8.3s<0.0s
# train: New cache created: /kaggle/working/Human-face-emotions-1/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 383.9±118.2 MB/s, size: 37.0 KB)
# val: Scanning /kaggle/working/Human-face-emotions-1/valid/labels... 1873 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1873/1873 1.3Kit/s 1.4s0.1s
# val: New cache created: /kaggle/working/Human-face-emotions-1/valid/labels.cache
# Plotting labels to /kaggle/working/runs/detect/train_kaggle/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.000833, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs/detect/train_kaggle
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/30      2.02G     0.8244      3.308      1.422         17        640: 100% ━━━━━━━━━━━━ 722/722 4.1it/s 2:55<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 59/59 4.9it/s 11.9s0.2s
#                    all       1873       1903      0.149      0.661       0.16      0.134
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/30       2.5G     0.5986      2.471      1.203         21        640: 100% ━━━━━━━━━━━━ 722/722 4.9it/s 2:28<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 59/59 5.4it/s 10.9s0.2s
#                    all       1873       1903      0.214      0.575      0.298      0.261
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/30      2.52G     0.5537      2.095      1.158         20        640: 100% ━━━━━━━━━━━━ 722/722 5.3it/s 2:17<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 59/59 5.4it/s 11.0s0.2s
#                    all       1873       1903       0.37      0.578      0.437      0.383
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/30      2.53G     0.5482      1.896      1.146         20        640: 100% ━━━━━━━━━━━━ 722/722 5.4it/s 2:13<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 59/59 5.6it/s 10.6s0.2s
#                    all       1873       1903      0.453      0.658       0.55      0.482
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/30      2.55G     0.5253      1.747      1.129         20        640: 100% ━━━━━━━━━━━━ 722/722 5.4it/s 2:13<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 59/59 5.8it/s 10.2s0.2s
#                    all       1873       1903      0.524      0.631      0.609      0.542
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/30      2.57G     0.5145      1.644      1.119         19        640: 100% ━━━━━━━━━━━━ 722/722 5.4it/s 2:13<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 59/59 6.0it/s 9.9s0.2s
#                    all       1873       1903       0.57      0.655      0.646      0.573
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/30      2.59G     0.5029      1.567       1.11         20        640: 100% ━━━━━━━━━━━━ 722/722 5.4it/s 2:13<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 59/59 6.0it/s 9.8s0.2s
#                    all       1873       1903      0.548      0.696       0.66      0.591
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/30       2.6G     0.4975      1.503      1.106         21        640: 100% ━━━━━━━━━━━━ 722/722 5.4it/s 2:13<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 59/59 6.1it/s 9.6s0.2s
#                    all       1873       1903      0.597      0.662      0.685      0.613
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/30      2.62G      0.491      1.444      1.101         18        640: 100% ━━━━━━━━━━━━ 722/722 5.4it/s 2:13<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 59/59 6.1it/s 9.6s0.2s
#                    all       1873       1903      0.606      0.678      0.695      0.626
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/30      2.63G     0.4853      1.404      1.097         22        640: 100% ━━━━━━━━━━━━ 722/722 5.4it/s 2:13<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 59/59 6.3it/s 9.4s0.2s
#                    all       1873       1903      0.622      0.697      0.722       0.65
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/30      2.66G     0.4826      1.369      1.096         18        640: 100% ━━━━━━━━━━━━ 722/722 5.4it/s 2:13<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 59/59 6.2it/s 9.5s0.2s
#                    all       1873       1903      0.604      0.698      0.711      0.642
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/30      2.67G      0.474      1.329      1.089         25        640: 100% ━━━━━━━━━━━━ 722/722 5.4it/s 2:13<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 59/59 6.2it/s 9.5s0.2s
#                    all       1873       1903      0.606      0.721      0.725      0.654
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/30      2.69G     0.4715       1.29      1.087         24        640: 100% ━━━━━━━━━━━━ 722/722 5.4it/s 2:13<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 59/59 6.3it/s 9.4s0.2s
#                    all       1873       1903      0.647      0.683      0.731      0.658
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/30       2.7G     0.4667      1.264      1.086         16        640: 100% ━━━━━━━━━━━━ 722/722 5.4it/s 2:13<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 59/59 6.3it/s 9.4s0.2s
#                    all       1873       1903      0.665        0.7      0.738      0.666
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/30      2.72G     0.4602      1.234      1.079         20        640: 100% ━━━━━━━━━━━━ 722/722 5.4it/s 2:13<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 59/59 6.2it/s 9.5s0.2s
#                    all       1873       1903      0.642      0.734      0.744      0.672
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/30      2.74G     0.4587      1.205      1.077         21        640: 100% ━━━━━━━━━━━━ 722/722 5.4it/s 2:13<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 59/59 6.2it/s 9.5s0.2s
#                    all       1873       1903       0.68      0.699      0.752       0.68
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/30      2.76G     0.4547      1.182      1.077         19        640: 100% ━━━━━━━━━━━━ 722/722 5.4it/s 2:13<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 59/59 6.3it/s 9.4s0.2s
#                    all       1873       1903      0.663      0.694      0.739       0.67
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/30      2.77G     0.4494      1.159       1.07         23        640: 100% ━━━━━━━━━━━━ 722/722 5.5it/s 2:12<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 59/59 6.2it/s 9.5s0.2s
#                    all       1873       1903      0.659      0.717      0.744      0.673
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/30      2.79G     0.4473      1.141      1.072         24        640: 100% ━━━━━━━━━━━━ 722/722 5.5it/s 2:12<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 59/59 6.3it/s 9.4s0.2s
#                    all       1873       1903      0.648       0.72      0.751      0.681
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/30       2.8G     0.4427      1.121      1.068         24        640: 100% ━━━━━━━━━━━━ 722/722 5.4it/s 2:13<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 59/59 6.3it/s 9.4s0.2s
#                    all       1873       1903      0.683      0.685      0.748      0.678
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/30      2.83G     0.3252     0.9121      1.037          8        640: 100% ━━━━━━━━━━━━ 722/722 5.4it/s 2:13<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 59/59 6.2it/s 9.5s0.2s
#                    all       1873       1903      0.708      0.653      0.751      0.681
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/30      2.84G     0.3118     0.8296       1.02          9        640: 100% ━━━━━━━━━━━━ 722/722 5.5it/s 2:12<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 59/59 6.3it/s 9.4s0.2s
#                    all       1873       1903      0.664      0.728      0.752      0.684
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/30      2.86G     0.3098     0.7894      1.017          8        640: 100% ━━━━━━━━━━━━ 722/722 5.5it/s 2:11<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 59/59 6.3it/s 9.4s0.2s
#                    all       1873       1903      0.692      0.691      0.752      0.686
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/30      2.87G     0.3017     0.7524      1.012          8        640: 100% ━━━━━━━━━━━━ 722/722 5.5it/s 2:11<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 59/59 6.3it/s 9.3s0.2s
#                    all       1873       1903      0.662      0.731      0.751      0.685
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/30      2.89G     0.2978     0.7226      1.009          8        640: 100% ━━━━━━━━━━━━ 722/722 5.5it/s 2:12<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 59/59 6.3it/s 9.3s0.2s
#                    all       1873       1903      0.715      0.673      0.753      0.687
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/30      2.91G     0.2964     0.6901      1.004          8        640: 100% ━━━━━━━━━━━━ 722/722 5.5it/s 2:12<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 59/59 6.3it/s 9.4s0.2s
#                    all       1873       1903      0.655      0.724       0.75      0.684
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/30      2.93G     0.2917     0.6653      1.003          8        640: 100% ━━━━━━━━━━━━ 722/722 5.5it/s 2:11<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 59/59 6.3it/s 9.3s0.2s
#                    all       1873       1903      0.683      0.699      0.746      0.681
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/30      2.94G     0.2901     0.6466      1.003          8        640: 100% ━━━━━━━━━━━━ 722/722 5.5it/s 2:12<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 59/59 6.3it/s 9.4s0.2s
#                    all       1873       1903      0.667      0.706      0.744      0.678
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/30      2.96G     0.2887     0.6219     0.9988          8        640: 100% ━━━━━━━━━━━━ 722/722 5.5it/s 2:12<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 59/59 6.4it/s 9.3s0.2s
#                    all       1873       1903      0.678      0.697      0.743      0.677
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/30      2.97G     0.2844     0.6174     0.9964          8        640: 100% ━━━━━━━━━━━━ 722/722 5.5it/s 2:12<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 59/59 6.3it/s 9.3s0.2s
#                    all       1873       1903      0.693       0.68      0.742      0.676
#
# 30 epochs completed in 1.205 hours.
# Optimizer stripped from /kaggle/working/runs/detect/train_kaggle/weights/last.pt, 6.3MB
# Optimizer stripped from /kaggle/working/runs/detect/train_kaggle/weights/best.pt, 6.3MB
#
# Validating /kaggle/working/runs/detect/train_kaggle/weights/best.pt...
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 73 layers, 3,007,208 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 59/59 5.5it/s 10.8s0.2s
#                    all       1873       1903      0.715      0.675      0.753      0.687
#                  anger        235        239       0.71      0.665      0.741       0.64
#                content        237        240      0.812       0.75      0.815      0.759
#                disgust        254        256      0.695      0.597      0.722      0.666
#                   fear        214        215       0.73      0.718      0.782      0.709
#                  happy        208        219      0.788      0.836      0.872      0.807
#                neutral        246        248      0.622      0.609      0.686      0.631
#                    sad        232        233      0.653      0.566      0.675       0.61
#               surprise        251        253       0.71       0.66       0.73      0.672
# Speed: 0.2ms preprocess, 2.0ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to /kaggle/working/runs/detect/train_kaggle
